# %%
import pandas as pd
import matplotlib.pyplot as plt


import os
import sys

sys.path.append(os.path.abspath("../src"))
from harmonization import (
    harmonize_classified_public_data,
    aggregate_public_data,
    aggregate_and_refine_public_data
)
from visualization import (
    plot_stacked_bar_public,
    plot_upsetplots_public
)

# %%
classified_public_data_path = "../data/public/all_additional_datasets.csv"

harmonized_public_data = harmonize_classified_public_data(classified_public_data_path)

aggregated_public_data = aggregate_public_data(harmonized_public_data)
aggregated_refined_public_data = aggregate_and_refine_public_data(harmonized_public_data)

# %% [markdown]
# Main Figures

# %%
plot_stacked_bar_public(aggregated_public_data)

# %%
plot_stacked_bar_public(aggregated_refined_public_data)

# %% [markdown]
# Supplementary Figures

# %%
plot_upsetplots_public(harmonized_public_data)
