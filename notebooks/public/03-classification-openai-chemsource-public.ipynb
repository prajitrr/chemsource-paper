# %%
import pandas as pd
from chemsource import ChemSource

# %%
import pandas as pd
from pandarallel import pandarallel
from chemsource import ChemSource


def classify_harmonized_dataset(dataset_path, model):
    dataset = pd.read_parquet(dataset_path)
    chem_source = ChemSource()
    classifications = []
    

    return dataset

def classify_all_public_data(drug_library_data_path, openai_api_key):
    model = ChemSource(
        model_api_key=openai_api_key,
        model="gpt-4o",
        clean_output=True,
        allowed_categories=["MEDICAL", "FOOD", "INDUSTRIAL", "PERSONAL CARE", "ENDOGENOUS", "INFO"]
    )

    pandarallel.initialize(n)
    return classify_harmonized_dataset(drug_library_data_path, model)

# %%
pd.read_parquet("../../data/public/retrieved/food_harmonized.parquet")
# Out:
#       FEATURE_ID                      COMPOUND_NAME  \
# 0             39                      Norspermidine
# 1            362                         spermidine
# 2            450                           spermine
# 3            488                         cadaverine
# 4            654                         histidinol
# ...          ...                                ...
# 2213      247951                        Methysticin
# 2214      247983                             Kawain
# 2215      247992  PE(22:6/0:0); [M+H]+ C27H45N1O7P1
# 2216      248022           (+/-)-Dihydromethysticin
# 2217      248091                         Piperyline
#
#                                                SYNONYMS  DETECTION_FREQUENCY  \
# 0     [Norspermidine, Bis(3-aminopropyl)amine, Dipro...             0.255859
# 1     [Spermidine, Spermidin, N-(3-aminopropyl)butan...             0.658203
# 2     [Spermine, Musculamine, Neuridine, Gerontine, ...             0.468750
# ...
